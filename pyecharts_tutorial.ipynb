# %% [markdown]
# # 简介
# 在这个教程中，我们将介绍pyecharts包。
#
# Echarts是百度开发的一个javascript可视化脚本，他的特点在于可交互（就是你鼠标移动上去，图片可以作出相应的变化）。小旭学长在echarts gallery发布了多款图表，累计12万的浏览量，获得300+赞，可以点击[这个链接](https://gallery.echartsjs.com/explore.html?u=bd-167860219&type=work#sort=rank~timeframe=all~author=all)查看
# echarts属于门槛比较高的一种可视化方法，需要写javascript，而javascript又是基于html网页，另外数据的处理还要用python，等于说你要熟练使用得同时会js，html，python三种语言。现在pyecharts出现了，直接在python里就可以调用生成echarts图片，大部分的图表只需要用python就可以生成，非常方便！
#
# 相比我们之前介绍的几种画图方法，各有各的优势，小旭学长的总结如下：
# >matplotlib：纯python出图，可批量出图，缺点是出的图片为静态图片无法交互
# folium：主要功能是绘制地图，javascript出图可交互，坐标系为wgs84，数据不需要转坐标
# echarts：可绘制各种图表，也能绘制地图，javascript出图可交互，但绘制地图时底图一般采用百度地图，需要转坐标系
#
# 那么，我们赶紧开始学习python的pyecharts包吧！

# %% [markdown]
# 最近新冠肺炎的疫情是相当的不妙。
# 小旭学长观察到，一些大型网站的疫情发布地图都是基于echarts的，那么我们基于pyecharts来实现一下数据地图可视化的操作吧
# 提供的基础数据是：
# <div class="alert alert-info"><h2>提供的基础数据是：</h2><p>
#     数据：<br>
#     不提供，我们数据从网上抓，无中生有<br>
#
#  </p></div>

# %% [markdown]
# # 数据获取

# %% [markdown]
# 很多网站都提供了疫情分布情况，数据都是公开的我们直接抓就行。这里以腾讯新闻的疫情发布链接为例，观察网络链接可以找到数据获取的访问请求

# %% [markdown]
# <img src="resource/yiqing.png"  style="width:800px">

# %% [markdown]
# 好的我们用最简单的方式把它抓下来，我们做省份的可视化

# %%
import urllib
import json
url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5'
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
datajson=json.loads(response.read().decode('utf8'))
datajson=json.loads(datajson['data'])
datajson
# Out:
# {'chinaTotal': {'confirm': 24377, 'suspect': 23260, 'dead': 492, 'heal': 920},
#  'chinaAdd': {'confirm': 3906, 'suspect': 46, 'dead': 67, 'heal': 288},
#  'lastUpdateTime': '2020-02-05 13:25:17',
#  'areaTree': [{'name': '中国',
#    'children': [{'name': '湖北',
#      'children': [{'name': '武汉',
#        'total': {'confirm': 8351, 'suspect': 0, 'dead': 362, 'heal': 368},
#        'today': {'confirm': 1967, 'suspect': 0, 'dead': 49, 'heal': 65}},
#       {'name': '黄冈',
#        'total': {'confirm': 1645, 'suspect': 0, 'dead': 25, 'heal': 50},
#        'today': {'confirm': 223, 'suspect': 0, 'dead': 6, 'heal': 11}},
#       {'name': '孝感',
#        'total': {'confirm': 1462, 'suspect': 0, 'dead': 18, 'heal': 6},
#        'today': {'confirm': 342, 'suspect': 0, 'dead': 1, 'heal': 2}},
#       {'name': '襄阳',
#        'total': {'confirm': 735, 'suspect': 0, 'dead': 2, 'heal': 7},
#        'today': {'confirm': 103, 'suspect': 0, 'dead': 1, 'heal': 0}},
#       {'name': '荆州',
#        'total': {'confirm': 713, 'suspect': 0, 'dead': 9, 'heal': 9},
#        'today': {'confirm': 100, 'suspect': 0, 'dead': 2, 'heal': 3}},
#       {'name': '随州',
#        'total': {'confirm': 706, 'suspect': 0, 'dead': 8, 'heal': 9},
#        'today': {'confirm': 65, 'suspect': 0, 'dead': 2, 'heal': 6}},
#       {'name': '黄石',
#        'total': {'confirm': 509, 'suspect': 0, 'dead': 2, 'heal': 18},
#        'today': {'confirm': 104, 'suspect': 0, 'dead': 0, 'heal': 8}},
#       {'name': '宜昌',
#        'total': {'confirm': 496, 'suspect': 0, 'dead': 4, 'heal': 9},
#        'today': {'confirm': 44, 'suspect': 0, 'dead': 1, 'heal': 7}},
#       {'name': '荆门',
#        'total': {'confirm': 422, 'suspect': 0, 'dead': 16, 'heal': 16},
#        'today': {'confirm': 22, 'suspect': 0, 'dead': 2, 'heal': 10}},
#       {'name': '咸宁',
#        'total': {'confirm': 384, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 36, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '鄂州',
#        'total': {'confirm': 382, 'suspect': 0, 'dead': 18, 'heal': 6},
#        'today': {'confirm': 50, 'suspect': 0, 'dead': 0, 'heal': 2}},
#       {'name': '十堰',
#        'total': {'confirm': 318, 'suspect': 0, 'dead': 0, 'heal': 9},
#        'today': {'confirm': 27, 'suspect': 0, 'dead': 0, 'heal': 3}},
#       {'name': '仙桃',
#        'total': {'confirm': 225, 'suspect': 0, 'dead': 4, 'heal': 0},
#        'today': {'confirm': 37, 'suspect': 0, 'dead': 1, 'heal': 0}},
#       {'name': '恩施州',
#        'total': {'confirm': 138, 'suspect': 0, 'dead': 0, 'heal': 6},
#        'today': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '天门',
#        'total': {'confirm': 128, 'suspect': 0, 'dead': 10, 'heal': 0},
#        'today': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '潜江',
#        'total': {'confirm': 54, 'suspect': 0, 'dead': 1, 'heal': 0},
#        'today': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '神农架',
#        'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '地区待确认',
#        'total': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 3}}],
#      'total': {'confirm': 16678, 'suspect': 0, 'dead': 479, 'heal': 520},
#      'today': {'confirm': 3156, 'suspect': 0, 'dead': 65, 'heal': 122}},
#     {'name': '浙江',
#      'children': [{'name': '温州',
#        'total': {'confirm': 364, 'suspect': 0, 'dead': 0, 'heal': 28},
#        'today': {'confirm': 24, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '杭州',
#        'total': {'confirm': 141, 'suspect': 0, 'dead': 0, 'heal': 14},
#        'today': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 8}},
#       {'name': '台州',
#        'total': {'confirm': 122, 'suspect': 0, 'dead': 0, 'heal': 11},
#        'today': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '宁波',
#        'total': {'confirm': 120, 'suspect': 0, 'dead': 0, 'heal': 4},
#        'today': {'confirm': 18, 'suspect': 0, 'dead': 0, 'heal': 2}},
#       {'name': '金华',
#        'total': {'confirm': 44, 'suspect': 0, 'dead': 0, 'heal': 6},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '绍兴',
#        'total': {'confirm': 30, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '嘉兴',
#        'total': {'confirm': 27, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '丽水',
#        'total': {'confirm': 16, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '衢州',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 2}},
#       {'name': '湖州',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '舟山',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 895, 'suspect': 0, 'dead': 0, 'heal': 72},
#      'today': {'confirm': 66, 'suspect': 0, 'dead': 0, 'heal': 12}},
#     {'name': '广东',
#      'children': [{'name': '深圳',
#        'total': {'confirm': 289, 'suspect': 0, 'dead': 0, 'heal': 13},
#        'today': {'confirm': 20, 'suspect': 0, 'dead': 0, 'heal': 3}},
#       {'name': '广州',
#        'total': {'confirm': 237, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 21, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '珠海',
#        'total': {'confirm': 69, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '佛山',
#        'total': {'confirm': 49, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '东莞',
#        'total': {'confirm': 44, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '中山',
#        'total': {'confirm': 35, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '惠州',
#        'total': {'confirm': 31, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '汕头',
#        'total': {'confirm': 20, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 3}},
#       {'name': '湛江',
#        'total': {'confirm': 18, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '阳江',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '肇庆',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '梅州',
#        'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '清远',
#        'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '江门',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '揭阳',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '韶关',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '茂名',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '汕尾',
#        'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '潮州',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '河源',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '地区待确认',
#        'total': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 2}}],
#      'total': {'confirm': 870, 'suspect': 0, 'dead': 0, 'heal': 32},
#      'today': {'confirm': 73, 'suspect': 0, 'dead': 0, 'heal': 8}},
#     {'name': '河南',
#      'children': [{'name': '信阳',
#        'total': {'confirm': 138, 'suspect': 0, 'dead': 0, 'heal': 6},
#        'today': {'confirm': 26, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '南阳',
#        'total': {'confirm': 107, 'suspect': 0, 'dead': 2, 'heal': 1},
#        'today': {'confirm': 8, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '郑州',
#        'total': {'confirm': 92, 'suspect': 0, 'dead': 0, 'heal': 19},
#        'today': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 6}},
#       {'name': '驻马店',
#        'total': {'confirm': 82, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '商丘',
#        'total': {'confirm': 61, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '周口',
#        'total': {'confirm': 56, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '新乡',
#        'total': {'confirm': 39, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '安阳',
#        'total': {'confirm': 35, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '平顶山',
#        'total': {'confirm': 34, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '漯河',
#        'total': {'confirm': 24, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '许昌',
#        'total': {'confirm': 24, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '洛阳',
#        'total': {'confirm': 17, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '开封',
#        'total': {'confirm': 17, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '焦作',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '鹤壁',
#        'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '三门峡',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '濮阳',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '济源示范区',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '地区待确认',
#        'total': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 12},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 8}}],
#      'total': {'confirm': 764, 'suspect': 0, 'dead': 2, 'heal': 47},
#      'today': {'confirm': 89, 'suspect': 0, 'dead': 0, 'heal': 14}},
#     {'name': '湖南',
#      'children': [{'name': '长沙',
#        'total': {'confirm': 164, 'suspect': 0, 'dead': 0, 'heal': 8},
#        'today': {'confirm': 16, 'suspect': 0, 'dead': 0, 'heal': 2}},
#       {'name': '岳阳',
#        'total': {'confirm': 89, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '邵阳',
#        'total': {'confirm': 68, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 13, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '常德',
#        'total': {'confirm': 56, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '娄底',
#        'total': {'confirm': 45, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '益阳',
#        'total': {'confirm': 40, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '衡阳',
#        'total': {'confirm': 39, 'suspect': 0, 'dead': 0, 'heal': 5},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '株洲',
#        'total': {'confirm': 38, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '怀化',
#        'total': {'confirm': 35, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '永州',
#        'total': {'confirm': 30, 'suspect': 0, 'dead': 0, 'heal': 5},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '郴州',
#        'total': {'confirm': 24, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '湘潭',
#        'total': {'confirm': 23, 'suspect': 0, 'dead': 0, 'heal': 4},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '湘西自治州',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '张家界',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 661, 'suspect': 0, 'dead': 0, 'heal': 37},
#      'today': {'confirm': 68, 'suspect': 0, 'dead': 0, 'heal': 4}},
#     {'name': '江西',
#      'children': [{'name': '南昌',
#        'total': {'confirm': 134, 'suspect': 0, 'dead': 0, 'heal': 7},
#        'today': {'confirm': 13, 'suspect': 0, 'dead': 0, 'heal': 3}},
#       {'name': '九江',
#        'total': {'confirm': 86, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 8, 'suspect': 0, 'dead': 0, 'heal': -1}},
#       {'name': '上饶',
#        'total': {'confirm': 69, 'suspect': 0, 'dead': 0, 'heal': 5},
#        'today': {'confirm': 19, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '新余',
#        'total': {'confirm': 69, 'suspect': 0, 'dead': 0, 'heal': 4},
#        'today': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '赣州',
#        'total': {'confirm': 48, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '宜春',
#        'total': {'confirm': 48, 'suspect': 0, 'dead': 0, 'heal': 4},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 2}},
#       {'name': '抚州',
#        'total': {'confirm': 44, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '萍乡',
#        'total': {'confirm': 22, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '吉安',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '鹰潭',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '景德镇',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 548, 'suspect': 0, 'dead': 0, 'heal': 27},
#      'today': {'confirm': 72, 'suspect': 0, 'dead': 0, 'heal': 7}},
#     {'name': '安徽',
#      'children': [{'name': '合肥',
#        'total': {'confirm': 93, 'suspect': 0, 'dead': 0, 'heal': 5},
#        'today': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '阜阳',
#        'total': {'confirm': 84, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '亳州',
#        'total': {'confirm': 58, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '安庆',
#        'total': {'confirm': 56, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '蚌埠',
#        'total': {'confirm': 48, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '六安',
#        'total': {'confirm': 34, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '马鞍山',
#        'total': {'confirm': 30, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '宿州',
#        'total': {'confirm': 24, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '芜湖',
#        'total': {'confirm': 23, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '铜陵',
#        'total': {'confirm': 19, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '淮北',
#        'total': {'confirm': 14, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '淮南',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '滁州',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '池州',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '黄山',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '宣城',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 530, 'suspect': 0, 'dead': 0, 'heal': 20},
#      'today': {'confirm': 50, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '重庆',
#      'children': [{'name': '万州区',
#        'total': {'confirm': 65, 'suspect': 0, 'dead': 1, 'heal': 1},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '九龙坡区',
#        'total': {'confirm': 19, 'suspect': 0, 'dead': 1, 'heal': 0},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '开州区',
#        'total': {'confirm': 18, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '云阳县',
#        'total': {'confirm': 18, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '江北区',
#        'total': {'confirm': 16, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '渝中区',
#        'total': {'confirm': 16, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '忠县',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '垫江县',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '两江新区',
#        'total': {'confirm': 14, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '綦江区',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '石柱县',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '渝北区',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '长寿区',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '巫溪县',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '合川区',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '奉节县',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '璧山区',
#        'total': {'confirm': 8, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '南岸区',
#        'total': {'confirm': 8, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '巫山县',
#        'total': {'confirm': 8, 'suspect': 0, 'dead': 0, 'heal': 4},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '荣昌区',
#        'total': {'confirm': 8, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '大足区',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '铜梁区',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '潼南区',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '大渡口区',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '丰都县',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '涪陵区',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '梁平区',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '巴南区',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '江津区',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '永川区',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '城口县',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '黔江区',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '沙坪坝区',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '高新区',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '彭水县',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '秀山县',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '武隆区',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 366, 'suspect': 0, 'dead': 2, 'heal': 14},
#      'today': {'confirm': 22, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '江苏',
#      'children': [{'name': '苏州',
#        'total': {'confirm': 55, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '南京',
#        'total': {'confirm': 47, 'suspect': 0, 'dead': 0, 'heal': 4},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '徐州',
#        'total': {'confirm': 45, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '无锡',
#        'total': {'confirm': 26, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '淮安',
#        'total': {'confirm': 26, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '泰州',
#        'total': {'confirm': 26, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '南通',
#        'total': {'confirm': 25, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '常州',
#        'total': {'confirm': 24, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '连云港',
#        'total': {'confirm': 20, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '扬州',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '盐城',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '宿迁',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '镇江',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 341, 'suspect': 0, 'dead': 0, 'heal': 13},
#      'today': {'confirm': 33, 'suspect': 0, 'dead': 0, 'heal': 1}},
#     {'name': '四川',
#      'children': [{'name': '成都',
#        'total': {'confirm': 92, 'suspect': 0, 'dead': 1, 'heal': 16},
#        'today': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 7}},
#       {'name': '南充',
#        'total': {'confirm': 28, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '广安',
#        'total': {'confirm': 24, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '绵阳',
#        'total': {'confirm': 17, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '达州',
#        'total': {'confirm': 17, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '内江',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '巴中',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '德阳',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '攀枝花',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '泸州',
#        'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '甘孜',
#        'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '自贡',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '宜宾',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '凉山',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '雅安',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '广元',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '遂宁',
#        'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '眉山',
#        'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '乐山',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '资阳',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '阿坝州',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '地区待确认',
#        'total': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 301, 'suspect': 0, 'dead': 1, 'heal': 23},
#      'today': {'confirm': 19, 'suspect': 0, 'dead': 0, 'heal': 9}},
#     {'name': '山东',
#      'children': [{'name': '青岛',
#        'total': {'confirm': 34, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '临沂',
#        'total': {'confirm': 30, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '济南',
#        'total': {'confirm': 29, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '威海',
#        'total': {'confirm': 27, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '烟台',
#        'total': {'confirm': 26, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '济宁',
#        'total': {'confirm': 23, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '德州',
#        'total': {'confirm': 19, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '枣庄',
#        'total': {'confirm': 17, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '潍坊',
#        'total': {'confirm': 16, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '日照',
#        'total': {'confirm': 14, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '淄博',
#        'total': {'confirm': 14, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '泰安',
#        'total': {'confirm': 14, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '聊城',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '菏泽',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '滨州',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 1}}],
#      'total': {'confirm': 298, 'suspect': 0, 'dead': 0, 'heal': 13},
#      'today': {'confirm': 23, 'suspect': 0, 'dead': 0, 'heal': 1}},
#     {'name': '北京',
#      'children': [{'name': '海淀',
#        'total': {'confirm': 45, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '朝阳',
#        'total': {'confirm': 43, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '西城',
#        'total': {'confirm': 29, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '大兴',
#        'total': {'confirm': 29, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '外地来京',
#        'total': {'confirm': 21, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '丰台',
#        'total': {'confirm': 20, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '昌平',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '通州',
#        'total': {'confirm': 13, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '房山',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '石景山',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '顺义',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '东城',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '怀柔',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '门头沟',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '延庆',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '地区待确认',
#        'total': {'confirm': 0, 'suspect': 0, 'dead': 1, 'heal': 20},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 1}}],
#      'total': {'confirm': 253, 'suspect': 0, 'dead': 1, 'heal': 24},
#      'today': {'confirm': 25, 'suspect': 0, 'dead': 0, 'heal': 1}},
#     {'name': '上海',
#      'children': [{'name': '外地来沪',
#        'total': {'confirm': 84, 'suspect': 0, 'dead': 0, 'heal': 5},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '浦东',
#        'total': {'confirm': 45, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '静安',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '徐汇',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '宝山',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '闵行',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '长宁',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '松江',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '奉贤',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '普陀',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '杨浦',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '虹口',
#        'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '黄浦',
#        'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '青浦',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '嘉定',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '金山',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '崇明',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '地区待确认',
#        'total': {'confirm': 0, 'suspect': 0, 'dead': 1, 'heal': 10},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 3}}],
#      'total': {'confirm': 233, 'suspect': 0, 'dead': 1, 'heal': 15},
#      'today': {'confirm': 14, 'suspect': 0, 'dead': 0, 'heal': 3}},
#     {'name': '福建',
#      'children': [{'name': '福州',
#        'total': {'confirm': 55, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '莆田',
#        'total': {'confirm': 38, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '泉州',
#        'total': {'confirm': 37, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '厦门',
#        'total': {'confirm': 21, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '漳州',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '宁德',
#        'total': {'confirm': 14, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '南平',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '三明',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '龙岩',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 205, 'suspect': 0, 'dead': 0, 'heal': 8},
#      'today': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 1}},
#     {'name': '黑龙江',
#      'children': [{'name': '哈尔滨',
#        'total': {'confirm': 73, 'suspect': 0, 'dead': 0, 'heal': 6},
#        'today': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 2}},
#       {'name': '绥化',
#        'total': {'confirm': 24, 'suspect': 0, 'dead': 2, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '齐齐哈尔',
#        'total': {'confirm': 20, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 14, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '双鸭山',
#        'total': {'confirm': 16, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '鸡西',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '大庆',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '佳木斯',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '牡丹江',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '七台河',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '大兴安岭',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '鹤岗',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '黑河',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 190, 'suspect': 0, 'dead': 2, 'heal': 6},
#      'today': {'confirm': 35, 'suspect': 0, 'dead': 0, 'heal': 2}},
#     {'name': '陕西',
#      'children': [{'name': '西安',
#        'total': {'confirm': 70, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '安康',
#        'total': {'confirm': 19, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 1}},
#       {'name': '汉中',
#        'total': {'confirm': 19, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '咸阳',
#        'total': {'confirm': 15, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '宝鸡',
#        'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '渭南',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '铜川',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '延安',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '商洛',
#        'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '榆林',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '韩城',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '杨凌示范区',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 165, 'suspect': 0, 'dead': 0, 'heal': 3},
#      'today': {'confirm': 23, 'suspect': 0, 'dead': 0, 'heal': 1}},
#     {'name': '广西',
#      'children': [{'name': '北海',
#        'total': {'confirm': 29, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '南宁',
#        'total': {'confirm': 28, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '桂林',
#        'total': {'confirm': 26, 'suspect': 0, 'dead': 0, 'heal': 4},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '柳州',
#        'total': {'confirm': 17, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '防城港',
#        'total': {'confirm': 13, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '河池',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '玉林',
#        'total': {'confirm': 8, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '梧州',
#        'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '贵港',
#        'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '钦州',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '贺州',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '百色',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 150, 'suspect': 0, 'dead': 0, 'heal': 10},
#      'today': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '河北',
#      'children': [{'name': '石家庄',
#        'total': {'confirm': 21, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '沧州',
#        'total': {'confirm': 20, 'suspect': 0, 'dead': 1, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '保定',
#        'total': {'confirm': 17, 'suspect': 0, 'dead': 0, 'heal': 2},
#        'today': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '邢台',
#        'total': {'confirm': 16, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '邯郸',
#        'total': {'confirm': 14, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '廊坊',
# ...
#       {'name': '平凉',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '甘南州',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '庆阳',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 57, 'suspect': 0, 'dead': 0, 'heal': 4},
#      'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '吉林',
#      'children': [{'name': '长春',
#        'total': {'confirm': 28, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '四平',
#        'total': {'confirm': 8, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '吉林',
#        'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '公主岭',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '延边',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '辽源',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '松原',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '通化',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 54, 'suspect': 0, 'dead': 0, 'heal': 1},
#      'today': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '内蒙古',
#      'children': [{'name': '鄂尔多斯',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '包头',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '呼和浩特',
#        'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '巴彦淖尔',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '呼伦贝尔',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '赤峰',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '乌兰察布',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '锡林郭勒',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '乌海',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '兴安盟乌兰浩特',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '通辽',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 42, 'suspect': 0, 'dead': 0, 'heal': 1},
#      'today': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '宁夏',
#      'children': [{'name': '银川',
#        'total': {'confirm': 20, 'suspect': 0, 'dead': 0, 'heal': 1},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '吴忠',
#        'total': {'confirm': 7, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '中卫',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '固原',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '宁东管委会',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '石嘴山',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 34, 'suspect': 0, 'dead': 0, 'heal': 1},
#      'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '新疆',
#      'children': [{'name': '乌鲁木齐',
#        'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '伊犁州',
#        'total': {'confirm': 9, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '兵团第九师',
#        'total': {'confirm': 4, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '昌吉州',
#        'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '吐鲁番',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '第七师',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '第八师石河子',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '阿克苏',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#       {'name': '六师五家渠',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 32, 'suspect': 0, 'dead': 0, 'heal': 0},
#      'today': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '香港',
#      'children': [{'name': '香港',
#        'total': {'confirm': 18, 'suspect': 0, 'dead': 1, 'heal': 0},
#        'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 18, 'suspect': 0, 'dead': 1, 'heal': 0},
#      'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '青海',
#      'children': [{'name': '西宁',
#        'total': {'confirm': 14, 'suspect': 0, 'dead': 0, 'heal': 3},
#        'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 3}},
#       {'name': '海北州',
#        'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 17, 'suspect': 0, 'dead': 0, 'heal': 3},
#      'today': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 3}},
#     {'name': '台湾',
#      'children': [{'name': '地区待确认',
#        'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 0},
#      'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '澳门',
#      'children': [{'name': '澳门',
#        'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 0},
#      'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#     {'name': '西藏',
#      'children': [{'name': '地区待确认',
#        'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#        'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#      'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#      'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#    'total': {'confirm': 24367, 'suspect': 0, 'dead': 492, 'heal': 920},
#    'today': {'confirm': 3852, 'suspect': 0, 'dead': 66, 'heal': 192}},
#   {'name': '泰国',
#    'total': {'confirm': 25, 'suspect': 0, 'dead': 0, 'heal': 8},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '新加坡',
#    'total': {'confirm': 24, 'suspect': 0, 'dead': 0, 'heal': 1},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '日本',
#    'total': {'confirm': 22, 'suspect': 0, 'dead': 0, 'heal': 1},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '韩国',
#    'total': {'confirm': 16, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '澳大利亚',
#    'total': {'confirm': 13, 'suspect': 0, 'dead': 0, 'heal': 2},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '德国',
#    'total': {'confirm': 12, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '美国',
#    'total': {'confirm': 11, 'suspect': 0, 'dead': 0, 'heal': 1},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '越南',
#    'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 3},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '马来西亚',
#    'total': {'confirm': 10, 'suspect': 0, 'dead': 0, 'heal': 1},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 1}},
#   {'name': '法国',
#    'total': {'confirm': 6, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '加拿大',
#    'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '阿联酋',
#    'total': {'confirm': 5, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '印度',
#    'total': {'confirm': 3, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '菲律宾',
#    'total': {'confirm': 2, 'suspect': 0, 'dead': 1, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '意大利',
#    'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '英国',
#    'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '俄罗斯',
#    'total': {'confirm': 2, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '尼泊尔',
#    'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '斯里兰卡',
#    'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 1},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '芬兰',
#    'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '瑞典',
#    'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '柬埔寨',
#    'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '比利时',
#    'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}},
#   {'name': '西班牙',
#    'total': {'confirm': 1, 'suspect': 0, 'dead': 0, 'heal': 0},
#    'today': {'confirm': 0, 'suspect': 0, 'dead': 0, 'heal': 0}}],
#  'chinaDayList': [{'date': '01.13',
#    'confirm': '41',
#    'suspect': '0',
#    'dead': '1',
#    'heal': '0'},
#   {'date': '01.14', 'confirm': '41', 'suspect': '0', 'dead': '1', 'heal': '0'},
#   {'date': '01.15', 'confirm': '41', 'suspect': '0', 'dead': '2', 'heal': '5'},
#   {'date': '01.16', 'confirm': '45', 'suspect': '0', 'dead': '2', 'heal': '8'},
#   {'date': '01.17',
#    'confirm': '62',
#    'suspect': '0',
#    'dead': '2',
#    'heal': '12'},
#   {'date': '01.18',
#    'confirm': '198',
#    'suspect': '0',
#    'dead': '3',
#    'heal': '17'},
#   {'date': '01.19',
#    'confirm': '275',
#    'suspect': '0',
#    'dead': '4',
#    'heal': '18'},
#   {'date': '01.20',
#    'confirm': '291',
#    'suspect': '54',
#    'dead': '6',
#    'heal': '25'},
#   {'date': '01.21',
#    'confirm': '440',
#    'suspect': '37',
#    'dead': '9',
#    'heal': '25'},
#   {'date': '01.22',
#    'confirm': '571',
#    'suspect': '393',
#    'dead': '17',
#    'heal': '25'},
#   {'date': '01.23',
#    'confirm': '830',
#    'suspect': '1072',
#    'dead': '25',
#    'heal': '34'},
#   {'date': '01.24',
#    'confirm': '1287',
#    'suspect': '1965',
#    'dead': '41',
#    'heal': '38'},
#   {'date': '01.25',
#    'confirm': '1975',
#    'suspect': '2684',
#    'dead': '56',
#    'heal': '49'},
#   {'date': '01.26',
#    'confirm': '2744',
#    'suspect': ' 5794',
#    'dead': '80',
#    'heal': '51'},
#   {'date': '01.27',
#    'confirm': '4515',
#    'suspect': '6973',
#    'dead': '106',
#    'heal': '60'},
#   {'date': '01.28',
#    'confirm': '5974',
#    'suspect': '9239',
#    'dead': '132',
#    'heal': '103'},
#   {'date': '01.29',
#    'confirm': '7711',
#    'suspect': '12167',
#    'dead': '170',
#    'heal': '124'},
#   {'date': '01.30',
#    'confirm': '9692',
#    'suspect': '15238',
#    'dead': '213',
#    'heal': '171'},
#   {'date': '01.31',
#    'confirm': '11791',
#    'suspect': '17988',
#    'dead': '259',
#    'heal': '243'},
#   {'date': '02.01',
#    'confirm': '14380',
#    'suspect': '19544',
#    'dead': '304',
#    'heal': '328'},
#   {'date': '02.02',
#    'confirm': '17236',
#    'suspect': '21558',
#    'dead': '361',
#    'heal': '475'},
#   {'date': '02.03',
#    'confirm': '20471',
#    'suspect': '23214',
#    'dead': '425',
#    'heal': '632'},
#   {'date': '02.04',
#    'confirm': '24363',
#    'suspect': '23260',
#    'dead': '491',
#    'heal': '892'}],
#  'chinaDayAddList': [{'date': '01.20',
#    'confirm': '77',
#    'suspect': '27',
#    'dead': '0',
#    'heal': '0'},
#   {'date': '01.21',
#    'confirm': '149',
#    'suspect': '53',
#    'dead': '3',
#    'heal': '0'},
#   {'date': '01.22',
#    'confirm': '131',
#    'suspect': '257',
#    'dead': '8',
#    'heal': '0'},
#   {'date': '01.23',
#    'confirm': '259',
#    'suspect': '680',
#    'dead': '8',
#    'heal': '6'},
#   {'date': '01.24',
#    'confirm': '444',
#    'suspect': '1118',
#    'dead': '16',
#    'heal': '3'},
#   {'date': '01.25',
#    'confirm': '688',
#    'suspect': '1309',
#    'dead': '15',
#    'heal': '11'},
#   {'date': '01.26',
#    'confirm': '769',
#    'suspect': '3806',
#    'dead': '24',
#    'heal': '2'},
#   {'date': '01.27',
#    'confirm': '1771',
#    'suspect': '2077',
#    'dead': '26',
#    'heal': '9'},
#   {'date': '01.28',
#    'confirm': '1459',
#    'suspect': '3248',
#    'dead': '26',
#    'heal': '43'},
#   {'date': '01.29',
#    'confirm': '1737',
#    'suspect': '4148',
#    'dead': '38',
#    'heal': '21'},
#   {'date': '01.30',
#    'confirm': '1982',
#    'suspect': '4812',
#    'dead': '43',
#    'heal': '47'},
#   {'date': '01.31',
#    'confirm': '2102',
#    'suspect': '5019',
#    'dead': '46',
#    'heal': '72'},
#   {'date': '02.01',
#    'confirm': '2590',
#    'suspect': '4562',
#    'dead': '45',
#    'heal': '85'},
#   {'date': '02.02',
#    'confirm': '2829',
#    'suspect': '5173',
#    'dead': '57',
#    'heal': '147'},
#   {'date': '02.03',
#    'confirm': '3235',
#    'suspect': '5072',
#    'dead': '64',
#    'heal': '157'},
#   {'date': '02.04',
#    'confirm': '3893',
#    'suspect': '3971',
#    'dead': '65',
#    'heal': '262'}],
#  'isShowAdd': True}

# %%
#提取各省份的数据
import pandas as pd
provincedata = pd.DataFrame(datajson['areaTree'][0]['children'])
provincedata.head(5)
# Out:
#   name                                           children  \
# 0   湖北  [{'name': '武汉', 'total': {'confirm': 8351, 'su...
# 1   浙江  [{'name': '温州', 'total': {'confirm': 364, 'sus...
# 2   广东  [{'name': '深圳', 'total': {'confirm': 289, 'sus...
# 3   河南  [{'name': '信阳', 'total': {'confirm': 138, 'sus...
# 4   湖南  [{'name': '长沙', 'total': {'confirm': 164, 'sus...
#
#                                                total  \
# 0  {'confirm': 16678, 'suspect': 0, 'dead': 479, ...
# 1  {'confirm': 895, 'suspect': 0, 'dead': 0, 'hea...
# 2  {'confirm': 870, 'suspect': 0, 'dead': 0, 'hea...
# 3  {'confirm': 764, 'suspect': 0, 'dead': 2, 'hea...
# 4  {'confirm': 661, 'suspect': 0, 'dead': 0, 'hea...
#
#                                                today
# 0  {'confirm': 3156, 'suspect': 0, 'dead': 65, 'h...
# 1  {'confirm': 66, 'suspect': 0, 'dead': 0, 'heal...
# 2  {'confirm': 73, 'suspect': 0, 'dead': 0, 'heal...
# 3  {'confirm': 89, 'suspect': 0, 'dead': 0, 'heal...
# 4  {'confirm': 68, 'suspect': 0, 'dead': 0, 'heal...

# %%
#整理一下数据，把total里面的数据展开
data1 = pd.DataFrame(provincedata['total'].apply(lambda r:[r]).sum())
data1['name'] = provincedata['name']
data1.head(5)
# Out:
#    confirm  suspect  dead  heal name
# 0    16678        0   479   520   湖北
# 1      895        0     0    72   浙江
# 2      870        0     0    32   广东
# 3      764        0     2    47   河南
# 4      661        0     0    37   湖南

# %% [markdown]
# 好的，到这一步我们已经获取了数据

# %% [markdown]
# # 可视化

# %% [markdown]
# ## 全国数据可视化

# %% [markdown]
# 官方配置文档：[pyecharts的地理图表教程](https://pyecharts.org/#/zh-cn/geography_charts)
# 首先我们要把数据整理成echarts认识的格式，就是如下：

# %%
data1[['name','confirm']].values
# Out:
# array([['湖北', 16678],
#        ['浙江', 895],
#        ['广东', 870],
#        ['河南', 764],
#        ['湖南', 661],
#        ['江西', 548],
#        ['安徽', 530],
#        ['重庆', 366],
#        ['江苏', 341],
#        ['四川', 301],
#        ['山东', 298],
#        ['北京', 253],
#        ['上海', 233],
#        ['福建', 205],
#        ['黑龙江', 190],
#        ['陕西', 165],
#        ['广西', 150],
#        ['河北', 135],
#        ['云南', 122],
#        ['海南', 91],
#        ['辽宁', 81],
#        ['山西', 81],
#        ['天津', 69],
#        ['贵州', 64],
#        ['甘肃', 57],
#        ['吉林', 54],
#        ['内蒙古', 42],
#        ['宁夏', 34],
#        ['新疆', 32],
#        ['香港', 18],
#        ['青海', 17],
#        ['台湾', 11],
#        ['澳门', 10],
#        ['西藏', 1]], dtype=object)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
#创建echarts对象c
c = (
    Map()#告诉echarts这个是Map形式的图表
    .add("确诊", data1[['name','confirm']].values, "china")#加一个数据，这个数据名叫”确诊“，数据的地图是echarts自带的china
    .set_global_opts(#对图表添加设置
        title_opts=opts.TitleOpts(title='疫情地图')#设置图表的名称
    )
)
#导出为html文件
c.render('疫情地图.html')

# %% [markdown]
# 打开目录下的 [疫情地图.html](疫情地图.html) 文件，效果如下
# <img src="resource/地图v1.png"  style="width:500px">
# 但是，我们还要在加一些美化调整，一些参数可以看[echarts官方的配置项手册](https://www.echartsjs.com/zh/option.html#title)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("确诊", 
         data1[['name','confirm']].values, 
         "china",
         is_roam = False,#不可鼠标缩放和平移漫游
         zoom = 1.2,#当前视角的缩放比例
         is_map_symbol_show = False, # 是否显示标记图形
         label_opts = opts.LabelOpts(position = 'inside'),#标签尽量放在图形区域内
        )
    .set_global_opts(
        title_opts=opts.TitleOpts(title='疫情地图'),
        visualmap_opts=opts.VisualMapOpts(is_piecewise=True,#设定分段颜色显示
                                          pieces=[{'min': 10000,'label':'10000人以上'}, #设定分段的值
                                                  {'min': 1000, 'max': 9999,'label':'1000-9999人'},
                                                  {'min': 500, 'max': 999,'label':'500-999人'},
                                                  {'min': 100, 'max': 499,'label':'100-499人'},
                                                  {'min': 10, 'max': 99,'label':'10-99人'},
                                                  {'min': 1, 'max': 9,'label':'1-9人'}],
                                           range_color=["#b4e0f3","#70b4eb","#1482e5","#1c3fbf","#070093" ] #调整显示颜色
                                         ),
    )
)
c.render('疫情地图.html')

# %% [markdown]
# 打开目录下的 [疫情地图.html](疫情地图.html) 文件，效果如下
# <img src="resource/地图2.png"  style="width:500px">

# %% [markdown]
# ## 单个省份数据可视化

# %%
import pandas as pd
#提取省份的数据
province = '广东'
guangdongdata = pd.DataFrame(provincedata[provincedata['name'] == province]['children'].iloc[0])
#整理一下数据，把total里面的数据展开
data2 = pd.DataFrame(guangdongdata['total'].apply(lambda r:[r]).sum())
data2['name'] = guangdongdata['name']+'市'
data2.head(5)
# Out:
#    confirm  suspect  dead  heal name
# 0      289        0     0    13  深圳市
# 1      237        0     0     3  广州市
# 2       69        0     0     1  珠海市
# 3       49        0     0     1  佛山市
# 4       44        0     0     0  东莞市

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("确诊", 
         data2[['name','confirm']].values, 
         province,
         is_roam = False,#不可鼠标缩放和平移漫游
         zoom = 1.2,#当前视角的缩放比例
         is_map_symbol_show = False, # 是否显示标记图形
         label_opts = opts.LabelOpts(position = 'inside'),#标签尽量放在图形区域内
        )
    .set_global_opts(
        title_opts=opts.TitleOpts(title=province+'疫情地图'),
        visualmap_opts=opts.VisualMapOpts(is_piecewise=True,#设定分段颜色显示
                                          pieces=[{'min': 200, 'label':'200人以上'},#设定分段的值
                                                  {'min': 100, 'max': 199,'label':'100-199人'},
                                                  {'min': 50, 'max': 99,'label':'50-99人'},
                                                  {'min': 10, 'max': 49,'label':'10-49人'},
                                                  {'min': 1, 'max': 9,'label':'1-9人'}],
                                           range_color=["#b4e0f3","#70b4eb","#1482e5","#1c3fbf","#070093" ] #调整显示颜色
                                         ),
    )
)
c.render(province+'疫情地图.html')

# %% [markdown]
# 打开目录下的 [广东疫情地图.html](广东疫情地图.html) 文件，效果如下
# <img src="resource/广东疫情地图.png"  style="width:500px">
